# %%
from preprocess import *
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pickle

sns.set_style('whitegrid')

# %% [markdown]
# ## I. Data collection and preprocessing
# The data contains labeled url links to articles online and .txt files. The following steps are followed for data collection and preprocessing: </n>
# 1. Texts were scraped from urls using BeautifulSoup4
# 2. Bad url links are dropped.
# 3. Fixed insufficient labeled samples.
# 4. Texts were extracted from .txt files and concatenated with the url samples, with the folder name encoded as class_id. Class_label was filled out accordingly.
#
# We ended up with: </n>
# Profile Report       100
# Situation Report      99
# Incident Report       88
# Analytical Report     74
# Total 381 samples.

# %%
df1 = pd.read_csv('data/document_characterisation_aicore_initial.csv')

# %%
df2 = pd.read_csv('data/DocumentDump.csv')

# %%
# drop rows with bad url links
df2 = df2[df2['URL'].str.startswith('http')]

# %%
df2.head()
# Out:
#                                                  URL              CLASS
# 0  https://issafrica.org/iss-today/time-to-tackle...  Analytical Report
# 1  http://www.understandingwar.org/backgrounder/r...  Analytical Report
# 2  http://www.understandingwar.org/backgrounder/r...  Analytical Report
# 3  http://www.understandingwar.org/backgrounder/w...  Analytical Report
# 4  http://www.understandingwar.org/backgrounder/r...  Analytical Report

# %%
df2.columns = ['url', 'class_label']

# %%
mapper = {
    'Incident Report': 0,
    'Situation Report': 1,
    'Profile Report': 2,
    'Analytical Report': 3
}

# %%
df2['class_id'] = df2['class_label'].map(mapper)
df1['class_label'][df1['class_label']=='Report'] = 'Profile Report'

# %%
df3 = pd.read_csv('data/public_urls.txt', sep='\n', header=None, names=['url', 'class_id'])
df3['class_id'] = 3
df3['class_label'] = 'Analytical Report'
df3.head()
# Out:
#                                                  url  class_id  \
# 0  https://www.csis.org/analysis/chronology-possi...         3
# 1  https://www.csis.org/analysis/reintroducing-am...         3
# 2  https://www.csis.org/analysis/us-japan-allianc...         3
# 3  https://www.csis.org/analysis/battle-mekelle-a...         3
# 4  https://www.longwarjournal.org/archives/2020/1...         3
#
#          class_label
# 0  Analytical Report
# 1  Analytical Report
# 2  Analytical Report
# 3  Analytical Report
# 4  Analytical Report

# %%
print(len(df1), len(df2), len(df3))
# Out:
# 60 117 27

# %%
df = pd.concat([df1, df2, df3], axis=0, join='outer', ignore_index=True)
print(len(df))
print(df['class_label'].value_counts())
df.tail(40)
# Out:
# 204
# Profile Report       100
# Analytical Report     50
# Situation Report      29
# Incident Report       25
# Name: class_label, dtype: int64
#                                                    url        class_label  \
# 164  https://rewardsforjustice.net/english/murat_ka...     Profile Report
# 165  https://rewardsforjustice.net/english/hamad_el...     Profile Report
# 166  https://rewardsforjustice.net/english/fuad_kha...     Profile Report
# 167  https://rewardsforjustice.net/english/bashir_m...     Profile Report
# 168  https://rewardsforjustice.net/english/mohamed_...     Profile Report
# 169  https://rewardsforjustice.net/english/abu_al_m...     Profile Report
# 170  https://rewardsforjustice.net/english/jehad_mo...     Profile Report
# 171  https://rewardsforjustice.net/english/ahmad_al...     Profile Report
# 172  https://rewardsforjustice.net/english/muhammad...     Profile Report
# 173  https://rewardsforjustice.net/english/abdelkar...     Profile Report
# 174  https://rewardsforjustice.net/english/muhammad...     Profile Report
# 175  https://rewardsforjustice.net/english/jamal_ra...     Profile Report
# 176  https://rewardsforjustice.net/english/ramadan_...     Profile Report
# 177  https://www.csis.org/analysis/chronology-possi...  Analytical Report
# 178  https://www.csis.org/analysis/reintroducing-am...  Analytical Report
# 179  https://www.csis.org/analysis/us-japan-allianc...  Analytical Report
# 180  https://www.csis.org/analysis/battle-mekelle-a...  Analytical Report
# 181  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 182  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 183  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 184  https://www.journalism.org/2020/11/23/american...  Analytical Report
# 185  https://www.journalism.org/2020/01/24/views-ab...  Analytical Report
# 186  https://www.journalism.org/2019/03/26/for-loca...  Analytical Report
# 187  https://www.journalism.org/2017/10/02/covering...  Analytical Report
# 188  https://ctc.usma.edu/afghanistans-future-emira...  Analytical Report
# 189  https://ctc.usma.edu/back-into-the-shadows-the...  Analytical Report
# 190  https://ctc.usma.edu/stepping-out-from-the-sha...  Analytical Report
# 191  https://www.csis.org/analysis/reintroducing-am...  Analytical Report
# 192  https://www.csis.org/analysis/us-japan-allianc...  Analytical Report
# 193  https://www.csis.org/analysis/battle-mekelle-a...  Analytical Report
# 194  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 195  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 196  https://www.longwarjournal.org/archives/2020/1...  Analytical Report
# 197  https://www.journalism.org/2020/11/23/american...  Analytical Report
# 198  https://www.journalism.org/2020/01/24/views-ab...  Analytical Report
# 199  https://www.journalism.org/2019/03/26/for-loca...  Analytical Report
# 200  https://www.journalism.org/2017/10/02/covering...  Analytical Report
# 201  https://ctc.usma.edu/afghanistans-future-emira...  Analytical Report
# 202  https://ctc.usma.edu/back-into-the-shadows-the...  Analytical Report
# 203  https://ctc.usma.edu/stepping-out-from-the-sha...  Analytical Report
#
#      class_id
# 164         2
# 165         2
# 166         2
# 167         2
# 168         2
# 169         2
# 170         2
# 171         2
# 172         2
# 173         2
# 174         2
# 175         2
# 176         2
# 177         3
# 178         3
# 179         3
# 180         3
# 181         3
# 182         3
# 183         3
# 184         3
# 185         3
# 186         3
# 187         3
# 188         3
# 189         3
# 190         3
# 191         3
# 192         3
# 193         3
# 194         3
# 195         3
# 196         3
# 197         3
# 198         3
# 199         3
# 200         3
# 201         3
# 202         3
# 203         3

# %%
# hide
# scrape texts from urls and save in the given directory
# bad_url = url_to_file(df, 'url', './data/text/')       

# Then hand scrape the rest with the bad_url

# %%
df['text'] = None
df = add_text_to_df('./data/text/', df, 'text')

# %%
df = text_to_df('data/0/', df, col_names=['text', 'class_id'])
df = text_to_df('data/1/', df, col_names=['text', 'class_id'])
df = text_to_df('data/3/', df, col_names=['text', 'class_id'])

# %%
mapper = {
    0: 'Incident Report',
    1: 'Situation Report',
    2: 'Profile Report',
    3: 'Analytical Report'
}
df['class_label'] = df['class_id'].map(mapper)
df['class_label'].value_counts()
# Out:
# Profile Report       100
# Situation Report      99
# Incident Report       88
# Analytical Report     74
# Name: class_label, dtype: int64

# %%
with open('data.pickle', 'wb') as handle:
    pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## II. Feature extraction

# %%
with open('data.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %% [markdown]
# ### II.a The iterative process:
# I start with a few hand crafted features I can think of and follow these iterative steps below to find more features. At the end of each random forest prediction, I look at the misclassified samples and try to study from the text what features could help improve the model: </n>
#
# Random forest -> Study misclassified -> Feature extraction -> Random forest ->...</n>
#
# Fit models using: </n>
# ```python
# from sklearn.model_selection import train_test_split
# X = df[list of features]
# y = df['class_label']
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y)
# cls_names = ['Incident Report', 'Situation Report', 'Profile report', 'Analytical report']
# rf = RandomForestClassifier(n_estimators=100, max_features=0.8, min_sample_leaf=2)
# rf.fit(X_train, y_train)
# y_pred = rf.predict(X_val)
# print(classification_report(y_val, y_pred, target_names=cls_names))
# print(confusion_matrix(y_val, y_pred))
# ```
# #### II.a.1 First, these features were extracted and fitted to a random forest model:</n>
# - Length of document: 'len'
# - Normalised count of organisations: 'org_count'
# - Normalised count of places: 'place_count'
# - Normalised count of times: 'time_count'
# - Normalised count of persons: 'person_count'
# - Normalised count of numbers: 'num_count' </n>
#
# All features were extracted using Spacy's [entity recoginition](https://spacy.io/api/annotation#named-entities) and [part of speech tagging](https://spacy.io/api/annotation#pos-tagging)
#
# Result:
# ```python
#
# Train:                    precision    recall  f1-score   support
#
#   Incident Report       0.97      0.98      0.97        59
#  Situation Report       0.96      0.99      0.97        70
#    Profile report       0.99      0.99      0.99        80
# Analytical report       0.99      0.95      0.97        79
#
#          accuracy                           0.98       288
#         macro avg       0.97      0.98      0.98       288
#      weighted avg       0.98      0.98      0.98       288
#
# Validation:                    precision    recall  f1-score   support
#
#   Incident Report       0.67      0.67      0.67        15
#  Situation Report       0.76      0.72      0.74        18
#    Profile report       0.68      0.75      0.71        20
# Analytical report       0.84      0.80      0.82        20
#
#          accuracy                           0.74        73
#         macro avg       0.74      0.73      0.74        73
#      weighted avg       0.74      0.74      0.74        73
#
# [[10  1  1  3]
#  [ 0 13  5  0]
#  [ 2  3 15  0]
#  [ 3  0  1 16]]
#
#  ```
# Looks like the model is on the way to something good. But not good yet. Notice the model confuses incident report with analytical report, and also with situation report with profile report.
#  ```python
# y_pred = rf.predict(X)
# compare = pd.DataFrame(y[y_pred!=y])
# compare['pred_label'] = y_pred[y_pred!=y]
# print(f'{len(compare)} misclassified')
# print(compare)
# 26 misclassified
#            class_label         pred_label
# 2      Incident Report  Analytical Report
# 17    Situation Report     Profile Report
# 24    Situation Report    Incident Report
# 53   Analytical Report   Situation Report
# 54   Analytical Report     Profile Report
# 57   Analytical Report   Situation Report
# 81    Situation Report  Analytical Report
# 96      Profile Report  Analytical Report
# 101     Profile Report  Analytical Report
# 109     Profile Report  Analytical Report
# 140     Profile Report    Incident Report
# 148     Profile Report    Incident Report
# 164     Profile Report    Incident Report
# 183  Analytical Report   Situation Report
# 202  Analytical Report   Situation Report
# 212    Incident Report     Profile Report
# 216    Incident Report     Profile Report
# 234    Incident Report     Profile Report
# 248    Incident Report     Profile Report
# 259    Incident Report     Profile Report
# 267   Situation Report    Incident Report
# 273   Situation Report     Profile Report
# 281   Situation Report  Analytical Report
# 307   Situation Report  Analytical Report
# 329   Situation Report    Incident Report
# 337  Analytical Report    Incident Report
# ```
# Looking at instances of misclassification, I have the following thoughts for improvement: </n>
#  1. incident report and analytical report maybe separated better using feature(s) of repeated NE. </n>
#  2. feature(s) of vocabulary could be useful to separate out analytical report. </n>
#  3. some information in other tags are not captured (header, strong, etc.), need to update scraper. </n>

# %% [markdown]
# #### II.a.2 Second, fix the scraper to include all texts not just texts in paragraphs and include 3 more features: </n>
# - Average number of repeats for entities: 'ents_rep'
# - Average number of repeats for entities of places, people and organisations: 'ppo_rep'
# - Normalised vocabulary (non-entity) count: 'vocab'. </n>
#
# ```python
#
# Train:                    precision    recall  f1-score   support
#
#   Incident Report       0.98      1.00      0.99        59
#  Situation Report       0.99      1.00      0.99        70
#    Profile report       1.00      1.00      1.00        80
# Analytical report       1.00      0.97      0.99        79
#
#          accuracy                           0.99       288
#         macro avg       0.99      0.99      0.99       288
#      weighted avg       0.99      0.99      0.99       288
#
# Validation:                    precision    recall  f1-score   support
#
#   Incident Report       0.83      0.67      0.74        15
#  Situation Report       0.72      0.72      0.72        18
#    Profile report       0.73      0.80      0.76        20
# Analytical report       0.90      0.95      0.93        20
#
#          accuracy                           0.79        73
#         macro avg       0.80      0.78      0.79        73
#      weighted avg       0.80      0.79      0.79        73
#
# [[10  2  2  1]
#  [ 0 13  4  1]
#  [ 1  3 16  0]
#  [ 1  0  0 19]]
#
# 17 misclassified
#            class_label         pred_label
# 24    Situation Report    Incident Report
# 48   Analytical Report    Incident Report
# 53   Analytical Report     Profile Report
# 75    Situation Report  Analytical Report
# 81    Situation Report  Analytical Report
# 86     Incident Report   Situation Report
# 96      Profile Report  Analytical Report
# 140     Profile Report    Incident Report
# 148     Profile Report    Incident Report
# 164     Profile Report    Incident Report
# 178  Analytical Report     Profile Report
# 202  Analytical Report   Situation Report
# 212    Incident Report     Profile Report
# 234    Incident Report     Profile Report
# 248    Incident Report     Profile Report
# 259    Incident Report     Profile Report
# 337  Analytical Report    Incident Report
#  ```
#
# There is good improvement in classifying analytical reports. However, situation report and profile report may have suffered slightly. </n>
#
# Comparing the misclassification lists. The common ones are: 24 s-i, 53 a-p, 81 s-a, 96 p-a, 140 p-i, 148 p-i, 164 p-i, 202 a-s, 212 i-p, 234 i-p, 248 i-p, 259 i-p, 337 a-i. </n>
#
# The most common misclassifications are between incident reports and profile reports. One feature that could be benefitial would be the use of past/present tenses in incident reports and profile reports. </n>
#
# In Spacy, verbs are annotated as follows: </n>
# - MD	VERB	VerbType=mod	verb, modal auxiliary </n>
# - VB	VERB	VerbForm=inf	verb, base form </n>
# - VBD	VERB	VerbForm=fin Tense=past	verb, past tense </n>
# - VBG	VERB	VerbForm=part Tense=pres Aspect=prog	verb, gerund or present participle </n>
# - VBN	VERB	VerbForm=part Tense=past Aspect=perf	verb, past participle </n>
# - VBP	VERB	VerbForm=fin Tense=pres	verb, non-3rd person singular present </n>
# - VBZ	VERB	VerbForm=fin Tense=pres Number=sing Person=three	verb, 3rd person singular present </n>

# %% [markdown]
# #### II.a.3 Third, we add in features on verb tenses past, present and modal auxiliary, and adjectives and adverbs: </n>
# - Normalised present tense verb count: 'verb_present'
# - Normalised past tense verb count: 'verb_past'
# - Normalised verb count: 'verb'
# - Normalised modal auxiliary count: 'modal'
# - Normalised adjective/adverbial count: 'ad'
#
# ```python
#  Train:                    precision    recall  f1-score   support
#
#   Incident Report       1.00      1.00      1.00        59
#  Situation Report       0.99      1.00      0.99        70
#    Profile report       1.00      1.00      1.00        80
# Analytical report       1.00      0.99      0.99        79
#
#          accuracy                           1.00       288
#         macro avg       1.00      1.00      1.00       288
#      weighted avg       1.00      1.00      1.00       288
#
# Validation:                    precision    recall  f1-score   support
#
#   Incident Report       0.71      0.80      0.75        15
#  Situation Report       0.89      0.94      0.92        18
#    Profile report       0.85      0.85      0.85        20
# Analytical report       0.88      0.75      0.81        20
#
#          accuracy                           0.84        73
#         macro avg       0.83      0.84      0.83        73
#      weighted avg       0.84      0.84      0.84        73
#
# [[12  1  0  2]
#  [ 0 17  1  0]
#  [ 2  1 17  0]
#  [ 3  0  2 15]]
#
# 13 misclassified
#            class_label         pred_label
# 48   Analytical Report   Situation Report
# 54   Analytical Report   Situation Report
# 77    Situation Report     Profile Report
# 81    Situation Report  Analytical Report
# 96      Profile Report  Analytical Report
# 109     Profile Report  Analytical Report
# 148     Profile Report    Incident Report
# 234    Incident Report     Profile Report
# 273   Situation Report  Analytical Report
# 281   Situation Report  Analytical Report
# 323   Situation Report     Profile Report
# 329   Situation Report    Incident Report
# 337  Analytical Report    Incident Report
# ```
#
#  As we can see there is markable improvement in average precision, recall and f1 score. Looking at the misclassfied cases again: the most misclassified were between analytical and situation reports, then situation and profile reports, and analytical and profile reports. </n>
#
# If looks as if introduction of modal auxiliary word count hasn't been able to distinguish analytical and situation reports. So I add count of adverbials of possiblity: </n>
# definitely, certainly, clearly, obviously, possibly, perhaps, probably, maybe, possible, definite, certain, obvious, likely.

# %% [markdown]
# #### II.a.4 Fourth, after adding adverbials and adjectives of probability.
# - Normalised count of adverbials and adjectives of probability: 'prob'
#
# ```python
# Train:                    precision    recall  f1-score   support
#
#   Incident Report       1.00      1.00      1.00        59
#  Situation Report       0.99      1.00      0.99        70
#    Profile report       1.00      1.00      1.00        80
# Analytical report       1.00      0.99      0.99        79
#
#          accuracy                           1.00       288
#         macro avg       1.00      1.00      1.00       288
#      weighted avg       1.00      1.00      1.00       288
#
# Validation:                    precision    recall  f1-score   support
#
#   Incident Report       0.81      0.87      0.84        15
#  Situation Report       0.94      0.89      0.91        18
#    Profile report       0.78      0.90      0.84        20
# Analytical report       0.94      0.80      0.86        20
#
#          accuracy                           0.86        73
#         macro avg       0.87      0.86      0.86        73
#      weighted avg       0.87      0.86      0.86        73
#
# [[13  0  1  1]
#  [ 0 16  2  0]
#  [ 1  1 18  0]
#  [ 2  0  2 16]]
#
#  11 misclassified
#            class_label         pred_label
# 48   Analytical Report   Situation Report
# 81    Situation Report  Analytical Report
# 96      Profile Report  Analytical Report
# 148     Profile Report    Incident Report
# 234    Incident Report     Profile Report
# 259    Incident Report     Profile Report
# 273   Situation Report  Analytical Report
# 281   Situation Report     Profile Report
# 323   Situation Report     Profile Report
# 329   Situation Report    Incident Report
# 337  Analytical Report     Profile Report
# ```
#
# There is a markable improvement in all scores. I am going to stop feature engineering here and focus on model selection and fine tuning in the next section. </n>
#
# The final feature extraction following the code below. Check out preprocessing.py for some code details.

# %%
df = tokenize_ft_extraction(df, 'text')
# Out:
# /Users/luluo/projects/doc-classification/preprocess.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ents_rep'][idx] = len(ents)/len(set(ents)) # repeat ratio of NE
# /Users/luluo/projects/doc-classification/preprocess.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vocab'][idx] = len(set(tokens))/len(tokens) # normalised vocabulary size
# /Users/luluo/projects/doc-classification/preprocess.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ppo_rep'][idx] = len(ppo)/(len(set(ppo)) + np.exp(float('-inf'))) # repeat retio of PPO
# /Users/luluo/projects/doc-classification/preprocess.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['no_ents_text'][idx] = ' '.join(tokens)
# /Users/luluo/projects/doc-classification/preprocess.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['verb_present'][idx] = len(verb_present)/len(tokens) # normalised present tense verb count
# /Users/luluo/projects/doc-classification/preprocess.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['verb_past'][idx] = len(verb_past)/len(tokens) # normalised past tense verb count
# /Users/luluo/projects/doc-classification/preprocess.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['verb'][idx] = len(verb)/len(tokens) # normalised verb count
# /Users/luluo/projects/doc-classification/preprocess.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['modal'][idx] = len(modal)/len(tokens) # normalised modal count
# /Users/luluo/projects/doc-classification/preprocess.py:185: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ad'][idx] = len(ad)/len(tokens) # normalised adjective/adverb count
# /Users/luluo/projects/doc-classification/preprocess.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prob'][idx] = len(prob)/len(tokens) # normalised count of advs and adjs of probability
# /Users/luluo/projects/doc-classification/preprocess.py:179: RuntimeWarning: invalid value encountered in double_scalars
#   df['ppo_rep'][idx] = len(ppo)/(len(set(ppo)) + np.exp(float('-inf'))) # repeat retio of PPO

# %%
df.head()
# Out:
#                                                  url      class_label  \
# 0  https://www.nytimes.com/2020/08/17/world/afric...  Incident Report
# 1     https://www.bbc.com/news/world-europe-54500555  Incident Report
# 2  https://www.aljazeera.com/news/2020/10/12/nago...  Incident Report
# 3  https://counteriedreport.com/roadside-bomb-bla...  Incident Report
# 4  https://counteriedreport.com/al-shabaabs-impro...  Incident Report
#
#    class_id                                               text ents_rep  \
# 0         0  advertisement supported by the extremist group...     1.52
# 1         0  belarusian riot police have used water cannon ...  1.41333
# 2         0  russian foreign minister calls on armenia and ...   2.2518
# 3         0  alshabaab ended 2019 with a truckborne improvi...     1.25
# 4         0  alshabaab ended 2019 with a truckborne improvi...     1.25
#
#       vocab  ppo_rep                                       no_ents_text  \
# 0  0.570312  1.71875  advertisement support extremist group ORG esca...
# 1   0.57716  1.54902  NORP riot police water cannon stun grenade bre...
# 2  0.372881  2.62887  NORP foreign minister call GPE GPE adhere agre...
# 3      0.75      1.5  GPE end DATE truckborne improvise explosive de...
# 4      0.75      1.5  GPE end DATE truckborne improvise explosive de...
#
#   verb_present  verb_past  ...         ad        prob  \
# 0     0.015625  0.0703125  ...   0.119792           0
# 1     0.037037  0.0432099  ...      0.125  0.00154321
# 2    0.0209847  0.0524617  ...  0.0992736  0.00161421
# 3    0.0277778   0.037037  ...   0.212963           0
# 4    0.0277778   0.037037  ...   0.212963           0
#
#                                             lem_text   len org_count  \
# 0  [advertisement, support, extremist, group, ORG...   384  0.059896
# 1  [NORP, riot, police, water, cannon, stun, gren...   648  0.030864
# 2  [NORP, foreign, minister, call, GPE, GPE, adhe...  1239  0.066182
# 3  [GPE, end, DATE, truckborne, improvise, explos...   108  0.027778
# 4  [GPE, end, DATE, truckborne, improvise, explos...   108  0.027778
#
#    place_count  time_count  person_count  num_count  ne_count
# 0     0.057292    0.039062      0.026042   0.015625  0.143229
# 1     0.026235    0.024691      0.064815   0.013889  0.121914
# 2     0.092010    0.033091      0.047619   0.012914  0.205811
# 3     0.027778    0.018519      0.000000   0.018519  0.055556
# 4     0.027778    0.018519      0.000000   0.018519  0.055556
#
# [5 rows x 22 columns]

# %%
# Manually fill out null 
df['ppo_rep'][df['ppo_rep'].isnull()] = 2

# %%
plt.figure(figsize=(18,8))
sns.histplot(df, x='len', hue='class_label', bins=500)
plt.xlim((0, 5000))
print('Average length of documents:', df['len'].mean())
print('Median length of documents:', df['len'].median())
# Out:
# Average length of documents: 653.8919667590028
# Median length of documents: 385.0

# %%
plt.figure(figsize=(8,10))
sns.boxplot(data=df, x='class_label', y='len')
plt.title('Length of text by report type')
# Out:
# Text(0.5, 1.0, 'Length of text by report type')

# %%
fig, axs = plt.subplots(nrows=8, ncols=2, figsize=(20, 40))
sns.boxplot(data=df, x='class_label', y='org_count', ax=axs[0][0])
axs[0][0].set_title('Organisation count by report class')
sns.boxplot(data=df, x='class_label', y='place_count', ax=axs[0][1])
axs[0][1].set_title('Place count by report class')
sns.boxplot(data=df, x='class_label', y='time_count', ax=axs[1][0])
axs[1][0].set_title('Times count by report class')
sns.boxplot(data=df, x='class_label', y='person_count', ax=axs[1][1])
axs[1][1].set_title('Persons count by report class')
sns.boxplot(data=df, x='class_label', y='num_count', ax=axs[2][0])
axs[2][0].set_title('Numbers count by report class')
sns.boxplot(data=df, x='class_label', y='ne_count', ax=axs[2][1])
axs[2][1].set_title('Named entity count by report class')
sns.boxplot(data=df, x='class_label', y='ents_rep', ax=axs[3][0])
axs[3][0].set_title('Average entity repeats by report class')
sns.boxplot(data=df, x='class_label', y='vocab', ax=axs[3][1])
axs[3][1].set_title('Non-entity vocab count by report class')
sns.boxplot(data=df, x='class_label', y='ppo_rep', ax=axs[4][0])
axs[4][0].set_title('Average place, person, organisation repeats by report class')
sns.boxplot(data=df, x='class_label', y='verb_present', ax=axs[4][1])
axs[4][1].set_title('Present tense verb count by report class')
sns.boxplot(data=df, x='class_label', y='verb_past', ax=axs[5][0])
axs[5][0].set_title('Past tense verb count by report class')
sns.boxplot(data=df, x='class_label', y='verb', ax=axs[5][1])
axs[5][1].set_title('Verb count by report class')
sns.boxplot(data=df, x='class_label', y='modal', ax=axs[6][0])
axs[6][0].set_title('Modal count by report class')
sns.boxplot(data=df, x='class_label', y='ad', ax=axs[6][1])
axs[6][1].set_title('Adverbial/Adjectives count by report class')
sns.boxplot(data=df, x='class_label', y='prob', ax=axs[7][0])
axs[7][0].set_title('Adverbial/Ajectives of probability count by report class')
# Out:
# Text(0.5, 1.0, 'Adverbial/Ajectives of probability count by report class')

# %%
X = df[['len', 'org_count', 'place_count', 'time_count', 'person_count', 'num_count', 'ents_rep', 'vocab', 'ppo_rep', 'verb_present', 'verb_past', 'verb', 'modal', 'ad', 'prob']]
y = df['class_label']
X_train, X_val, y_train, y_val = train_test_split( X, y, test_size=0.2, stratify=y, random_state=2020)

# %%
cls_names = ['Incident Report', 'Situation Report', 'Profile report', 'Analytical report']
rf = RandomForestClassifier(
    n_estimators=500, 
    max_features=0.8, 
    # max_depth=10, 
    min_samples_leaf=2,
    random_state=2020
)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)
print('Train:', classification_report(y_train, rf.predict(X_train), target_names=cls_names))
print('Validation:', classification_report(y_val, y_pred, target_names=cls_names))
print(confusion_matrix(y_val, y_pred))
# Out:
# Train:                    precision    recall  f1-score   support
#
#   Incident Report       1.00      1.00      1.00        59
#  Situation Report       0.99      1.00      0.99        70
#    Profile report       1.00      1.00      1.00        80
# Analytical report       1.00      0.99      0.99        79
#
#          accuracy                           1.00       288
#         macro avg       1.00      1.00      1.00       288
#      weighted avg       1.00      1.00      1.00       288
#
# Validation:                    precision    recall  f1-score   support
#
#   Incident Report       0.81      0.87      0.84        15
#  Situation Report       0.94      0.89      0.91        18
#    Profile report       0.78      0.90      0.84        20
# Analytical report       0.94      0.80      0.86        20
#
#          accuracy                           0.86        73
#         macro avg       0.87      0.86      0.86        73
#      weighted avg       0.87      0.86      0.86        73
#
# [[13  0  1  1]
#  [ 0 16  2  0]
#  [ 1  1 18  0]
#  [ 2  0  2 16]]

# %%
y_pred = rf.predict(X)
compare = pd.DataFrame(y[y_pred!=y])
compare['pred_label'] = y_pred[y_pred!=y]
print(f'{len(compare)} misclassified')
print(compare)
# Out:
# 11 misclassified
#            class_label         pred_label
# 48   Analytical Report   Situation Report
# 81    Situation Report  Analytical Report
# 96      Profile Report  Analytical Report
# 148     Profile Report    Incident Report
# 234    Incident Report     Profile Report
# 259    Incident Report     Profile Report
# 273   Situation Report  Analytical Report
# 281   Situation Report     Profile Report
# 323   Situation Report     Profile Report
# 329   Situation Report    Incident Report
# 337  Analytical Report     Profile Report

# %% [markdown]
# ## III. Finalise model

# %% [markdown]
# ### III.a Random forest
#
# Random search CV is conducted on the training data to find the best hyperparameters.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, f1_score
scoring = make_scorer(f1_score, average='micro')

X = df[['len', 'org_count', 'place_count', 'time_count', 'person_count', 'num_count', 'ents_rep', 'vocab', 'ppo_rep', 'verb_present', 'verb_past', 'verb', 'modal', 'ad', 'prob']]
y = df['class_label']
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, stratify=y, random_state=2020)
rf = RandomForestClassifier()
parameter_space = {
                'n_estimators': [100, 300],
                'max_depth': [5, 10],
                'min_samples_split': [2, 5],
                'min_samples_leaf': [1, 5],
                'bootstrap': [True]
            }

rf_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=parameter_space,
    scoring=scoring,
    n_iter=10,
    cv=10,
    verbose=0,
    random_state=42,
    n_jobs=-1
)

rf_search.fit(X_train, y_train)
print('Best parameters are:', rf_search.best_params_)
print()
print('F1 score:', rf_search.best_score_)
print()

y_test_pred = rf_search.best_estimator_.predict(X_test)
print('Test result:', classification_report(y_test, y_test_pred, target_names=cls_names))
# Out:
# Best parameters are: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True}
#
# F1 score: 0.8124384236453203
#
# Test result:                    precision    recall  f1-score   support
#
#   Incident Report       0.88      0.93      0.90        15
#  Situation Report       0.94      0.83      0.88        18
#    Profile report       0.78      0.90      0.84        20
# Analytical report       0.94      0.85      0.89        20
#
#          accuracy                           0.88        73
#         macro avg       0.88      0.88      0.88        73
#      weighted avg       0.88      0.88      0.88        73

# %% [markdown]
# ### III.b CatBoost

# %%
import catboost as cb
parameter_space = {
    'depth': [4, 7],
    'learning_rate': [0.15, 0.3, 0.8],
    'l2_leaf_reg': [4, 9, 15],
    'iterations': [500]
}
cb_clf = cb.CatBoostClassifier()
cb_search = RandomizedSearchCV(
    estimator=cb_clf,
    param_distributions=parameter_space,
    scoring=scoring,
    n_iter=10,
    cv=10,
    verbose=0,
    random_state=42,
    n_jobs=-1
)

cb_search.fit(X_train, y_train)
print('Best parameters are:', cb_search.best_params_)
print()
print('F1 score:', cb_search.best_score_)
print()

y_test_pred = cb_search.best_estimator_.predict(X_test)
print('Test result:', classification_report(y_test, y_test_pred, target_names=cls_names))
# Out:
# ms	remaining: 832ms
# 128:	learn: 0.2155862	total: 288ms	remaining: 828ms
# 129:	learn: 0.2147506	total: 290ms	remaining: 824ms
# 130:	learn: 0.2129314	total: 291ms	remaining: 821ms
# 131:	learn: 0.2126206	total: 293ms	remaining: 817ms
# 132:	learn: 0.2115435	total: 295ms	remaining: 813ms
# 133:	learn: 0.2097746	total: 296ms	remaining: 809ms
# 134:	learn: 0.2093545	total: 298ms	remaining: 805ms
# 135:	learn: 0.2082878	total: 302ms	remaining: 808ms
# 136:	learn: 0.2079082	total: 304ms	remaining: 804ms
# 137:	learn: 0.2073500	total: 305ms	remaining: 801ms
# 138:	learn: 0.2060911	total: 307ms	remaining: 798ms
# 139:	learn: 0.2045679	total: 309ms	remaining: 794ms
# 140:	learn: 0.2035909	total: 310ms	remaining: 790ms
# 141:	learn: 0.2021765	total: 312ms	remaining: 786ms
# 142:	learn: 0.2013787	total: 314ms	remaining: 783ms
# 143:	learn: 0.2001053	total: 317ms	remaining: 785ms
# 144:	learn: 0.1992022	total: 319ms	remaining: 781ms
# 145:	learn: 0.1986916	total: 321ms	remaining: 777ms
# 146:	learn: 0.1981134	total: 322ms	remaining: 774ms
# 147:	learn: 0.1970686	total: 324ms	remaining: 770ms
# 148:	learn: 0.1962918	total: 326ms	remaining: 767ms
# 149:	learn: 0.1953685	total: 327ms	remaining: 764ms
# 150:	learn: 0.1947245	total: 330ms	remaining: 762ms
# 151:	learn: 0.1942454	total: 333ms	remaining: 761ms
# 152:	learn: 0.1919232	total: 334ms	remaining: 758ms
# 153:	learn: 0.1912760	total: 336ms	remaining: 754ms
# 154:	learn: 0.1900758	total: 338ms	remaining: 751ms
# 155:	learn: 0.1892882	total: 339ms	remaining: 748ms
# 156:	learn: 0.1869516	total: 341ms	remaining: 745ms
# 157:	learn: 0.1863847	total: 343ms	remaining: 741ms
# 158:	learn: 0.1841188	total: 346ms	remaining: 743ms
# 464:	learn: 0.0538732	total: 997ms	remaining: 75.1ms
# 465:	learn: 0.0537657	total: 999ms	remaining: 72.9ms
# 466:	learn: 0.0536294	total: 1s	remaining: 70.7ms
# 467:	learn: 0.0534406	total: 1s	remaining: 68.5ms
# 468:	learn: 0.0533763	total: 1s	remaining: 66.3ms
# 469:	learn: 0.0533268	total: 1s	remaining: 64.2ms
# 470:	learn: 0.0530611	total: 1.01s	remaining: 62ms
# 471:	learn: 0.0529825	total: 1.01s	remaining: 59.8ms
# 472:	learn: 0.0528449	total: 1.01s	remaining: 57.8ms
# 473:	learn: 0.0525470	total: 1.01s	remaining: 55.6ms
# 474:	learn: 0.0524683	total: 1.01s	remaining: 53.4ms
# 475:	learn: 0.0522785	total: 1.02s	remaining: 51.3ms
# 476:	learn: 0.0520951	total: 1.02s	remaining: 49.1ms
# 477:	learn: 0.0520807	total: 1.02s	remaining: 46.9ms
# 478:	learn: 0.0518652	total: 1.02s	remaining: 44.8ms
# 479:	learn: 0.0517121	total: 1.02s	remaining: 42.6ms
# 480:	learn: 0.0516194	total: 1.03s	remaining: 40.6ms
# 481:	learn: 0.0515161	total: 1.03s	remaining: 38.4ms
# 482:	learn: 0.0514826	total: 1.03s	remaining: 36.3ms
# 483:	learn: 0.0512566	total: 1.03s	remaining: 34.2ms
# 484:	learn: 0.0511608	total: 1.04s	remaining: 32.1ms
# 485:	learn: 0.0509555	total: 1.04s	remaining: 30ms
# 486:	learn: 0.0508587	total: 1.04s	remaining: 27.9ms
# 487:	learn: 0.0507175	total: 1.05s	remaining: 25.7ms
# 488:	learn: 0.0506734	total: 1.05s	remaining: 23.6ms
# 489:	learn: 0.0505288	total: 1.05s	remaining: 21.5ms
# 490:	learn: 0.0503077	total: 1.05s	remaining: 19.3ms
# 491:	learn: 0.0501959	total: 1.06s	remaining: 17.2ms
# 492:	learn: 0.0500516	total: 1.06s	remaining: 15ms
# 493:	learn: 0.0499163	total: 1.06s	remaining: 12.9ms
# 494:	learn: 0.0497680	total: 1.06s	remaining: 10.7ms
# 495:	learn: 0.0495788	total: 1.07s	remaining: 8.6ms
# 496:	learn: 0.0494640	total: 1.07s	remaining: 6.47ms
# 497:	learn: 0.0493965	total: 1.07s	remaining: 4.31ms
# 498:	learn: 0.0492761	total: 1.07s	remaining: 2.15ms
# 499:	learn: 0.0490898	total: 1.08s	remaining: 0us
# Best parameters are: {'learning_rate': 0.15, 'l2_leaf_reg': 4, 'iterations': 500, 'depth': 4}
#
# F1 score: 0.8229064039408867
#
# Test result:                    precision    recall  f1-score   support
#
#   Incident Report       0.86      0.80      0.83        15
#  Situation Report       0.93      0.78      0.85        18
#    Profile report       0.72      0.90      0.80        20
# Analytical report       0.89      0.85      0.87        20
#
#          accuracy                           0.84        73
#         macro avg       0.85      0.83      0.84        73
#      weighted avg       0.85      0.84      0.84        73

# %% [markdown]
# There might be better hyperparameters for CatBoost what produce better result. However for the limited time for training, random forest is sufficient and very quick to run too.

# %% [markdown]
# ## IV Save the best model

# %%
model_path = './model/rf_model.sav'
pickle.dump(rf_search.best_estimator_, open(model_path, 'wb'))
